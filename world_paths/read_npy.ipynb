# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = np.load("/home/r0hit/catkin_ws/src/drdo-interiit22/path_taken_world2_local_coord.npy")
df = df.T
df = df[:, :3]
# df2 = np.load('/home/r0hit/catkin_ws/src/drdo-interiit22/Full_World1_RUN.npy')
print(df.shape)
# Out:
# (554, 3)

# %%
plt.scatter(df[:, 0], df[:, 1], color='r')
# plt.scatter(df2[:, 0], df2[:, 1], color='b') 
plt.show()
